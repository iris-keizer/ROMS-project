# %% [markdown]
# ## Notebook to prepare the ERA5 data to be able to save the datasets locally
#
# The next step would be to create the datasets for lateral forcing.
#
# In this notebook:
# -
#
# The ERA5 data is:
# -
#
# The data is downloaded from: https://cds.climate.copernicus.eu/cdsapp#!/dataset/reanalysis-era5-single-levels
# and from: https://cds.climate.copernicus.eu/cdsapp#!/dataset/reanalysis-era5-single-levels-preliminary-back-extension

# %%
# Import necessary packages

import dask
import xarray as xr

from tqdm import tqdm

dask.config.set({"array.slicing.split_large_chunks": False})

# %%
# Load the different datasets as one dataset when they have similar sampling frequency

era5_hourly = xr.open_mfdataset('/Users/iriskeizer/Documents/ROMS/data/ERA5/raw/1979_2022/hourly/*.nc')
#era5_6hourly = xr.open_mfdataset('/Users/iriskeizer/Documents/ROMS/data/ERA5/raw/1979_2022/6hourly/*.nc')
#era5_12hourly = xr.open_mfdataset('/Users/iriskeizer/Documents/ROMS/data/ERA5/raw/1979_2022/12hourly/*.nc')
#era5_daily = xr.open_mfdataset('/Users/iriskeizer/Documents/ROMS/data/ERA5/raw/1979_2022/daily/*.nc')

# %%
era5_hourly

# %%
era5_daily
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 153, latitude: 137, expver: 2, time: 31548)
# Coordinates:
#   * longitude  (longitude) float32 -24.0 -23.75 -23.5 -23.25 ... 13.5 13.75 14.0
#   * latitude   (latitude) float32 66.0 65.75 65.5 65.25 ... 32.5 32.25 32.0
#   * expver     (expver) int32 1 5
#   * time       (time) datetime64[ns] 1979-01-01T12:00:00 ... 2022-03-10
# Data variables:
#     ssr        (time, expver, latitude, longitude) float32 dask.array<chunksize=(31548, 2, 137, 153), meta=np.ndarray>
# Attributes:
#     Conventions:  CF-1.6
#     history:      2022-03-14 13:34:13 GMT by grib_to_netcdf-2.24.2: /opt/ecmw...

# %%
# Delete 2022

era5_hourly = era5_hourly.where(era5_hourly.time.dt.year < 2022, drop = True)
#era5_6hourly = era5_6hourly.where(era5_6hourly.time.dt.year < 2022, drop = True)
#era5_12hourly = era5_12hourly.where(era5_12hourly.time.dt.year < 2022, drop = True)
#era5_daily = era5_daily.where(era5_daily.time.dt.year < 2022, drop = True)
# Out:
# /Users/iriskeizer/opt/anaconda3/lib/python3.9/site-packages/xarray/core/indexing.py:1227: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# /Users/iriskeizer/opt/anaconda3/lib/python3.9/site-packages/xarray/core/indexing.py:1227: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# /Users/iriskeizer/opt/anaconda3/lib/python3.9/site-packages/xarray/core/indexing.py:1227: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]

# %%
# Delete attributes as they aren't valid anymore

del era5_hourly.attrs['Conventions']
del era5_hourly.attrs['history']
del era5_6hourly.attrs['Conventions']
del era5_6hourly.attrs['history']
del era5_12hourly.attrs['Conventions']
del era5_12hourly.attrs['history']
del era5_daily.attrs['Conventions']
del era5_daily.attrs['history']

# %%
# Delete expver = 5

era5_hourly = era5_hourly.sel(expver = 1).drop('expver')
era5_6hourly = era5_6hourly.sel(expver = 1).drop('expver')
era5_12hourly = era5_12hourly.sel(expver = 1).drop('expver')
era5_daily = era5_daily.sel(expver = 1).drop('expver')

# %%
era5_daily.ssr
# Out:
# <xarray.DataArray 'ssr' (time: 31411, latitude: 137, longitude: 153)>
# dask.array<getitem, shape=(31411, 137, 153), dtype=float32, chunksize=(31411, 137, 153), chunktype=numpy.ndarray>
# Coordinates:
#   * longitude  (longitude) float32 -24.0 -23.75 -23.5 -23.25 ... 13.5 13.75 14.0
#   * latitude   (latitude) float32 66.0 65.75 65.5 65.25 ... 32.5 32.25 32.0
#   * time       (time) datetime64[ns] 1979-01-01T12:00:00 ... 2021-12-31T12:00:00
# Attributes:
#     units:          J m**-2
#     long_name:      Surface net solar radiation
#     standard_name:  surface_net_downward_shortwave_flux

# %%
# Save data


era5_hourly.tp.to_netcdf('/Users/iriskeizer/Documents/ROMS/data/ERA5/preprocessed/hourly/era5_hourly_tp.nc')
era5_hourly.ssr.to_netcdf('/Users/iriskeizer/Documents/ROMS/data/ERA5/preprocessed/hourly/era5_hourly_ssr.nc')

era5_6hourly.d2m.to_netcdf('/Users/iriskeizer/Documents/ROMS/data/ERA5/preprocessed/6hourly/era5_6hourly_d2m.nc')
era5_6hourly.msl.to_netcdf('/Users/iriskeizer/Documents/ROMS/data/ERA5/preprocessed/6hourly/era5_6hourly_msl.nc')
era5_6hourly.t2m.to_netcdf('/Users/iriskeizer/Documents/ROMS/data/ERA5/preprocessed/6hourly/era5_6hourly_t2m.nc')
era5_6hourly.tcc.to_netcdf('/Users/iriskeizer/Documents/ROMS/data/ERA5/preprocessed/6hourly/era5_6hourly_tcc.nc')
era5_6hourly.v10.to_netcdf('/Users/iriskeizer/Documents/ROMS/data/ERA5/preprocessed/6hourly/era5_6hourly_v10.nc')
era5_6hourly.u10.to_netcdf('/Users/iriskeizer/Documents/ROMS/data/ERA5/preprocessed/6hourly/era5_6hourly_u10.nc')


era5_12hourly.tp.to_netcdf('/Users/iriskeizer/Documents/ROMS/data/ERA5/preprocessed/12hourly/era5_12hourly_tp.nc')

era5_daily.ssr.to_netcdf('/Users/iriskeizer/Documents/ROMS/data/ERA5/preprocessed/daily/era5_daily_ssr.nc')

# %%
era5_hourly = xr.open_mfdataset('/Users/iriskeizer/Documents/ROMS/data/ERA5/raw/1979_2022/hourly/*.nc')


era5_hourly = era5_hourly.where(era5_hourly.time.dt.year < 2022, drop = True)


del era5_hourly.attrs['Conventions']
del era5_hourly.attrs['history']

era5_hourly = era5_hourly.sel(expver = 1).drop('expver')

era5_hourly.tp.to_netcdf('/Users/iriskeizer/Documents/ROMS/data/ERA5/preprocessed/hourly/era5_hourly_tp.nc')
era5_hourly.ssr.to_netcdf('/Users/iriskeizer/Documents/ROMS/data/ERA5/preprocessed/hourly/era5_hourly_ssr.nc')
