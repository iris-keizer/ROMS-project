# %% [markdown]
# # Notebook to check the ORA-20C data
#
# This needs to be done as there seem to be values missing in some versions of the data.

# %%
import xarray as xr

# %%
data_processed = xr.open_dataset('/Users/iriskeizer/Documents/ROMS/data/ORA20C/opa0_prepared.nc')
data_processed1 = xr.open_dataset('/Users/iriskeizer/Documents/ROMS/data/ORA20C/opa1_prepared.nc')

# %% [markdown]
# ### Plot ensemble member #0

# %%
# Plot monthly data per year to check whether values are NaN

data_processed.zos.sel(time = data_processed.time.dt.year.isin([1950])).sortby(['lat', 'lon']).plot(col = 'time', col_wrap = 6, cbar_kwargs={'orientation': 'horizontal'})

# %%
data_processed.zos.sel(time = data_processed.time.dt.year.isin([1951])).sortby(['lat', 'lon']).plot(col = 'time', col_wrap = 6, cbar_kwargs={'orientation': 'horizontal'})

# %%
data_processed.zos.sel(time = data_processed.time.dt.year.isin([1952])).sortby(['lat', 'lon']).plot(col = 'time', col_wrap = 6, cbar_kwargs={'orientation': 'horizontal'})

# %%
data_processed.zos.sel(time = data_processed.time.dt.year.isin([1953])).sortby(['lat', 'lon']).plot(col = 'time', col_wrap = 6, cbar_kwargs={'orientation': 'horizontal'})

# %% [markdown]
# Clearly there already is a problem in this dataset where some years have NaN values

# %% [markdown]
# ### Plot ensemble member #1

# %%
# Plot monthly data per year to check whether values are NaN

data_processed1.zos.sel(time = data_processed1.time.dt.year.isin([1950])).sortby(['lat', 'lon']).plot(col = 'time', col_wrap = 6, cbar_kwargs={'orientation': 'horizontal'})

# %%
data_processed1.zos.sel(time = data_processed1.time.dt.year.isin([1951])).sortby(['lat', 'lon']).plot(col = 'time', col_wrap = 6, cbar_kwargs={'orientation': 'horizontal'})

# %%
data_processed1.zos.sel(time = data_processed1.time.dt.year.isin([1952])).sortby(['lat', 'lon']).plot(col = 'time', col_wrap = 6, cbar_kwargs={'orientation': 'horizontal'})

# %%
data_processed1.zos.sel(time = data_processed1.time.dt.year.isin([1954])).sortby(['lat', 'lon']).plot(col = 'time', col_wrap = 6, cbar_kwargs={'orientation': 'horizontal'})

# %% [markdown]
# This seems much more hopefull, maybe here there are no NaN values

# %%
data_processed1_annual = data_processed1.groupby('time.year').mean()

# %%
data_processed1_annual.zos.sortby(['lat', 'lon']).plot(col = 'year', col_wrap = 10, cbar_kwargs={'orientation': 'horizontal'})
