# %% [markdown]
# ## Notebook to prepare the glorys data to be used for the lateral forcing

# %%
import xarray as xr

# %%
# Import downloaded data

# %%
data = xr.open_dataset('/Users/iriskeizer/Documents/ROMS/data/GLORYS12V1/processed/glorys.nc')

# %%
data.vo
# Out:
# <xarray.DataArray 'vo' (time: 324, depth: 50, latitude: 409, longitude: 457)>
# [3027990600 values with dtype=float32]
# Coordinates:
#   * time       (time) datetime64[ns] 1993-01-16T12:00:00 ... 2019-12-16T12:00:00
#   * depth      (depth) float32 0.494 1.541 2.646 ... 5.275e+03 5.728e+03
#   * latitude   (latitude) float32 32.0 32.08 32.17 32.25 ... 65.83 65.92 66.0
#   * longitude  (longitude) float32 -24.0 -23.92 -23.83 ... 13.83 13.92 14.0
# Attributes:
#     long_name:      Northward velocity
#     standard_name:  northward_sea_water_velocity
#     units:          m s-1
#     unit_long:      Meters per second
#     cell_methods:   area: mean
#     _ChunkSizes:    [  1   7 341 720]
