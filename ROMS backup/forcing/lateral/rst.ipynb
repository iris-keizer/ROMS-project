# %%
import xarray as xr

# %%
rst = xr.open_dataset('/Users/iriskeizer/Documents/ROMS/data/ROMS output/spinup2/NorthSea4_rst.nc')

# %%
rst
# Out:
# <xarray.Dataset>
# Dimensions:        (tracer: 2, boundary: 4, s_rho: 30, s_w: 31, eta_rho: 110,
#                     xi_rho: 122, eta_u: 110, xi_u: 121, eta_v: 109, xi_v: 122,
#                     eta_psi: 109, xi_psi: 121, ocean_time: 2)
# Coordinates:
#   * s_rho          (s_rho) float64 -0.9833 -0.95 -0.9167 ... -0.05 -0.01667
#   * s_w            (s_w) float64 -1.0 -0.9667 -0.9333 ... -0.06667 -0.03333 0.0
#     lon_rho        (eta_rho, xi_rho) float64 ...
#     lat_rho        (eta_rho, xi_rho) float64 ...
#     lon_u          (eta_u, xi_u) float64 ...
#     lat_u          (eta_u, xi_u) float64 ...
#     lon_v          (eta_v, xi_v) float64 ...
#     lat_v          (eta_v, xi_v) float64 ...
#     lon_psi        (eta_psi, xi_psi) float64 ...
#     lat_psi        (eta_psi, xi_psi) float64 ...
#   * ocean_time     (ocean_time) datetime64[ns] 1960-01-08 1960-01-13
# Dimensions without coordinates: tracer, boundary, eta_rho, xi_rho, eta_u, xi_u,
# ...

# %%
315360000/150
# Out:
# 2102400.0

# %%
1575417600/150
# Out:
# 10502784.0

# %%
river = xr.open_dataset('/Users/iriskeizer/Documents/ROMS/timnorthsea8/forcing/Rivers_NorthSea8_smooth013_Dai2014_AnnualCycle_1993-2019.nc')

ocean_time = river.river_time[23:25].data

# %%
ocean_time
# Out:
# array(['1949-12-15T00:00:00.000000000', '1950-01-15T00:00:00.000000000'],
#       dtype='datetime64[ns]')

# %%
rst['ocean_time']
# Out:
# <xarray.DataArray 'ocean_time' (ocean_time: 2)>
# array(['1960-01-08T00:00:00.000000000', '1960-01-13T00:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * ocean_time  (ocean_time) datetime64[ns] 1960-01-08 1960-01-13
# Attributes:
#     standard_name:  time
#     long_name:      time since initialization
#     field:          time

# %%
rst['ocean_time'] = ocean_time

# %%
rst.ocean_time
# Out:
# <xarray.DataArray 'ocean_time' (ocean_time: 2)>
# array(['1949-12-15T00:00:00.000000000', '1950-01-15T00:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * ocean_time  (ocean_time) datetime64[ns] 1949-12-15 1950-01-15

# %%
rst.ocean_time.attrs = {'long_name' : 'seconds since 1948-01-01 00:00:00',
                        'field' : 'time, scalar, series'}
rst.ocean_time.encoding = {'units' : 'seconds since 1948-01-01 00:00:00',
                        'calendar' : 'standard'}

# %%
rst
# Out:
# <xarray.Dataset>
# Dimensions:        (tracer: 2, boundary: 4, s_rho: 30, s_w: 31, eta_rho: 110,
#                     xi_rho: 122, eta_u: 110, xi_u: 121, eta_v: 109, xi_v: 122,
#                     eta_psi: 109, xi_psi: 121, ocean_time: 2)
# Coordinates:
#   * s_rho          (s_rho) float64 -0.9833 -0.95 -0.9167 ... -0.05 -0.01667
#   * s_w            (s_w) float64 -1.0 -0.9667 -0.9333 ... -0.06667 -0.03333 0.0
#     lon_rho        (eta_rho, xi_rho) float64 -19.88 -19.63 ... 9.631 9.877
#     lat_rho        (eta_rho, xi_rho) float64 35.95 35.95 35.95 ... 61.91 61.91
#     lon_u          (eta_u, xi_u) float64 -19.75 -19.51 -19.26 ... 9.508 9.754
#     lat_u          (eta_u, xi_u) float64 35.95 35.95 35.95 ... 61.91 61.91 61.91
#     lon_v          (eta_v, xi_v) float64 -19.88 -19.63 -19.39 ... 9.631 9.877
#     lat_v          (eta_v, xi_v) float64 36.1 36.1 36.1 ... 61.82 61.82 61.82
#     lon_psi        (eta_psi, xi_psi) float64 -19.75 -19.51 ... 9.508 9.754
# ...

# %%
rst.to_netcdf('/Users/iriskeizer/Documents/ROMS/data/restart/spinup3/NorthSea4_rst.nc')

# %%
2678400/150
# Out:
# 17856.0

# %%
12623040-17856
# Out:
# 12605184

# %%
rst = xr.open_dataset('/Users/iriskeizer/Documents/ROMS/data/restart/spinup1/NorthSea4_rst.nc')

# %%
rst.ocean_time
# Out:
# <xarray.DataArray 'ocean_time' ()>
# array('1950-01-15T00:00:00.000000000', dtype='datetime64[ns]')
# Coordinates:
#     ocean_time  datetime64[ns] 1950-01-15
