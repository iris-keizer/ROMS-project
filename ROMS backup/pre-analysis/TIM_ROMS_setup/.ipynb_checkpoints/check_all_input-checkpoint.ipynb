# %% [markdown]
# ## Notebook to check and compare all input files

# %%
import xarray as xr

# %%
rivers = xr.open_dataset('/Users/iriskeizer/Documents/ROMS/timnorthsea8/forcing/Rivers_NorthSea8_smooth013_Dai2014_AnnualCycle_1993-2019.nc')
rivers
# Out:
# <xarray.Dataset>
# Dimensions:          (river: 63, river_time: 864, s_rho: 30)
# Coordinates:
#   * river            (river) float64 44.0 87.0 113.0 116.0 ... 882.0 890.0 895.0
#   * river_time       (river_time) datetime64[ns] 1948-01-15 ... 2019-12-15
#   * s_rho            (s_rho) float64 -0.9833 -0.95 -0.9167 ... -0.05 -0.01667
# Data variables:
#     river_direction  (river) float64 ...
#     river_Xposition  (river) int32 ...
#     river_Eposition  (river) int32 ...
#     river_temp       (river_time, s_rho, river) float64 ...
#     river_salt       (river_time, s_rho, river) float64 ...
#     river_Vshape     (s_rho, river) float64 ...
#     river_transport  (river_time, river) float64 ...
# Attributes:
#     creation_date:  Tue Nov 19 09:16:29 CET 2019
#     title:          Roms river forcing for AnnualCycle case

# %%
data_an = xr.open_dataset('/Users/iriskeizer/Documents/ROMS/timnorthsea8/forcing/ERA5_NorthAtlantic_an_ForROMS.nc')
data_an
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 37984, lat: 137, lon: 153)
# Coordinates:
#   * time     (time) datetime64[ns] 1993-01-01 ... 2018-12-31T18:00:00
#   * lon      (lon) float32 -24.0 -23.75 -23.5 -23.25 ... 13.25 13.5 13.75 14.0
#   * lat      (lat) float32 32.0 32.25 32.5 32.75 33.0 ... 65.25 65.5 65.75 66.0
# Data variables:
#     Uwind    (time, lat, lon) float32 ...
#     Vwind    (time, lat, lon) float32 ...
#     cloud    (time, lat, lon) float32 ...
#     Pair     (time, lat, lon) float32 ...
#     Tair     (time, lat, lon) float32 ...
#     Qair     (time, lat, lon) float32 ...

# %%
data_fc = xr.open_dataset('/Users/iriskeizer/Documents/ROMS/timnorthsea8/forcing/ERA5_NorthAtlantic_fc_ForROMS.nc')
data_fc
# Out:
# <xarray.Dataset>
# Dimensions:     (time_rain: 18992, lat: 137, lon: 153, time_swrad: 9496)
# Coordinates:
#   * time_rain   (time_rain) datetime64[ns] 1993-01-01T06:00:00 ... 2018-12-31...
#   * time_swrad  (time_swrad) datetime64[ns] 1993-01-01T12:00:00 ... 2018-12-3...
#   * lon         (lon) float32 -24.0 -23.75 -23.5 -23.25 ... 13.5 13.75 14.0
#   * lat         (lat) float32 32.0 32.25 32.5 32.75 ... 65.25 65.5 65.75 66.0
# Data variables:
#     rain        (time_rain, lat, lon) float32 ...
#     swrad       (time_swrad, lat, lon) float32 ...

# %%
smooth_bry = xr.open_dataset('/Users/iriskeizer/Documents/ROMS/timnorthsea8/forcing/NS8_smooth013_glorys12v1_bry_19930115_to_20181231.nc')
smooth_bry
# Out:
# <xarray.Dataset>
# Dimensions:     (eta_rho: 218, xi_rho: 242, eta_u: 218, xi_u: 241, eta_v: 217, xi_v: 242, eta_psi: 217, xi_psi: 241, s_rho: 30, s_w: 31, ocean_time: 312)
# Coordinates:
#     lon_rho     (eta_rho, xi_rho) float64 ...
#     lat_rho     (eta_rho, xi_rho) float64 ...
#   * s_rho       (s_rho) float64 -0.9833 -0.95 -0.9167 ... -0.05 -0.01667
#   * s_w         (s_w) float64 -1.0 -0.9667 -0.9333 ... -0.06667 -0.03333 0.0
#   * ocean_time  (ocean_time) datetime64[ns] 1993-01-15 1993-02-15 ... 2018-12-15
# Dimensions without coordinates: eta_rho, xi_rho, eta_u, xi_u, eta_v, xi_v, eta_psi, xi_psi
# Data variables: (12/43)
#     lon_u       (eta_u, xi_u) float64 ...
#     lat_u       (eta_u, xi_u) float64 ...
#     lon_v       (eta_v, xi_v) float64 ...
#     lat_v       (eta_v, xi_v) float64 ...
#     lat_psi     (eta_psi, xi_psi) float64 ...
#     lon_psi     (eta_psi, xi_psi) float64 ...
#     ...          ...
#     vbar_south  (ocean_time, xi_v) float32 ...
# ...

# %%
smooth_clim = xr.open_dataset('/Users/iriskeizer/Documents/ROMS/timnorthsea8/forcing/NS8_smooth013_glorys12v1_clim_19930115_to_20181231.nc')
smooth_clim
# Out:
# <xarray.Dataset>
# Dimensions:     (eta_rho: 218, xi_rho: 242, eta_u: 218, xi_u: 241, eta_v: 217, xi_v: 242, eta_psi: 217, xi_psi: 241, s_rho: 30, s_w: 31, ocean_time: 312)
# Coordinates:
#   * s_rho       (s_rho) float64 -0.9833 -0.95 -0.9167 ... -0.05 -0.01667
#   * s_w         (s_w) float64 -1.0 -0.9667 -0.9333 ... -0.06667 -0.03333 0.0
#   * ocean_time  (ocean_time) datetime64[ns] 1993-01-15 1993-02-15 ... 2018-12-15
# Dimensions without coordinates: eta_rho, xi_rho, eta_u, xi_u, eta_v, xi_v, eta_psi, xi_psi
# Data variables: (12/28)
#     lon_rho     (eta_rho, xi_rho) float64 ...
#     lat_rho     (eta_rho, xi_rho) float64 ...
#     lon_u       (eta_u, xi_u) float64 ...
#     lat_u       (eta_u, xi_u) float64 ...
#     lon_v       (eta_v, xi_v) float64 ...
#     lat_v       (eta_v, xi_v) float64 ...
#     ...          ...
#     v           (ocean_time, s_rho, eta_v, xi_v) float32 ...
#     salt        (ocean_time, s_rho, eta_rho, xi_rho) float32 ...
# ...

# %%
smooth_sponge_nudg = xr.open_dataset('/Users/iriskeizer/Documents/ROMS/timnorthsea8/NorthSea8_smooth013_sponge_nudg.nc')
smooth_sponge_nudg
# Out:
# <xarray.Dataset>
# Dimensions:           (s_rho: 30, s_w: 31, eta_rho: 218, xi_rho: 242, bath: 1, eta_u: 218, xi_u: 241, eta_v: 217, xi_v: 242, eta_psi: 217, xi_psi: 241, eta_vert: 219, xi_vert: 243)
# Coordinates:
#   * s_rho             (s_rho) float64 -0.9833 -0.95 -0.9167 ... -0.05 -0.01667
#   * s_w               (s_w) float64 -1.0 -0.9667 -0.9333 ... -0.03333 0.0
# Dimensions without coordinates: eta_rho, xi_rho, bath, eta_u, xi_u, eta_v, xi_v, eta_psi, xi_psi, eta_vert, xi_vert
# Data variables: (12/44)
#     theta_s           float64 ...
#     theta_b           float64 ...
#     Tcline            float64 ...
#     hc                float64 ...
#     Cs_r              (s_rho) float64 ...
#     Cs_w              (s_w) float64 ...
#     ...                ...
#     mask_u            (eta_u, xi_u) float64 ...
#     mask_v            (eta_v, xi_v) float64 ...
#     mask_psi          (eta_psi, xi_psi) float64 ...
#     tracer_NudgeCoef  (s_rho, eta_rho, xi_rho) float64 ...
# ...

# %%
smooth_sponge_nudg = xr.open_dataset('/Users/iriskeizer/Documents/ROMS/timnorthsea8/changed files/NorthSea8_smooth013_sponge_nudg.nc')
smooth_sponge_nudg
# Out:
# <xarray.Dataset>
# Dimensions:           (s_rho: 30, s_w: 31, eta_rho: 218, xi_rho: 242, bath: 1, eta_u: 218, xi_u: 241, eta_v: 217, xi_v: 242, eta_psi: 217, xi_psi: 241, eta_vert: 219, xi_vert: 243)
# Coordinates:
#   * s_rho             (s_rho) float64 -0.9833 -0.95 -0.9167 ... -0.05 -0.01667
#   * s_w               (s_w) float64 -1.0 -0.9667 -0.9333 ... -0.03333 0.0
# Dimensions without coordinates: eta_rho, xi_rho, bath, eta_u, xi_u, eta_v, xi_v, eta_psi, xi_psi, eta_vert, xi_vert
# Data variables: (12/44)
#     theta_s           float64 ...
#     theta_b           float64 ...
#     Tcline            float64 ...
#     hc                float64 ...
#     Cs_r              (s_rho) float64 ...
#     Cs_w              (s_w) float64 ...
#     ...                ...
#     mask_u            (eta_u, xi_u) float64 ...
#     mask_v            (eta_v, xi_v) float64 ...
#     mask_psi          (eta_psi, xi_psi) float64 ...
#     tracer_NudgeCoef  (s_rho, eta_rho, xi_rho) float64 ...
# ...

# %%
smooth_sponge_nudg.y_u.plot()

# %%
smooth_sponge_nudg.spherical
# Out:
# <xarray.DataArray 'spherical' ()>
# array(b'', dtype='|S1')
# Attributes:
#     long_name:  Grid type logical switch

# %%
smooth_nv = xr.open_dataset('/Users/iriskeizer/Documents/ROMS/timnorthsea8/NorthSea8_rst_Y2019_14_01_2018_NoneVar.nc')
smooth_nv
# Out:
# <xarray.Dataset>
# Dimensions:        (ocean_time: 1, eta_rho: 218, xi_rho: 242, eta_u: 218, xi_u: 241, eta_v: 217, xi_v: 242, eta_psi: 217, xi_psi: 241, s_rho: 30, s_w: 31, tracer: 2, boundary: 4)
# Coordinates:
#   * ocean_time     (ocean_time) datetime64[ns] 1993-01-15
#     lon_rho        (eta_rho, xi_rho) float64 ...
#     lat_rho        (eta_rho, xi_rho) float64 ...
#     lon_u          (eta_u, xi_u) float64 ...
#     lat_u          (eta_u, xi_u) float64 ...
#     lon_v          (eta_v, xi_v) float64 ...
#     lat_v          (eta_v, xi_v) float64 ...
#     lon_psi        (eta_psi, xi_psi) float64 ...
#     lat_psi        (eta_psi, xi_psi) float64 ...
#   * s_rho          (s_rho) float64 -0.9833 -0.95 -0.9167 ... -0.05 -0.01667
#   * s_w            (s_w) float64 -1.0 -0.9667 -0.9333 ... -0.06667 -0.03333 0.0
# Dimensions without coordinates: eta_rho, xi_rho, eta_u, xi_u, eta_v, xi_v, eta_psi, xi_psi, tracer, boundary
# Data variables: (12/38)
# ...

# %%
smooth_nv.lon_v.plot()

# %%
smooth_sponge_nudg_dewi = xr.open_dataset('/Users/iriskeizer/Documents/ROMS/timnorthsea8/NorthSea8_smooth01_sponge_nudg.nc')

# %%
smooth_sponge_nudg_dewi
# Out:
# <xarray.Dataset>
# Dimensions:           (s_rho: 30, s_w: 31, eta_rho: 218, xi_rho: 242, bath: 1, eta_u: 218, xi_u: 241, eta_v: 217, xi_v: 242, eta_psi: 217, xi_psi: 241, eta_vert: 219, xi_vert: 243)
# Coordinates:
#   * s_rho             (s_rho) float64 -0.9833 -0.95 -0.9167 ... -0.05 -0.01667
#   * s_w               (s_w) float64 -1.0 -0.9667 -0.9333 ... -0.03333 0.0
# Dimensions without coordinates: eta_rho, xi_rho, bath, eta_u, xi_u, eta_v, xi_v, eta_psi, xi_psi, eta_vert, xi_vert
# Data variables: (12/44)
#     theta_s           float64 ...
#     theta_b           float64 ...
#     Tcline            float64 ...
#     hc                float64 ...
#     Cs_r              (s_rho) float64 ...
#     Cs_w              (s_w) float64 ...
#     ...                ...
#     mask_u            (eta_u, xi_u) float64 ...
#     mask_v            (eta_v, xi_v) float64 ...
#     mask_psi          (eta_psi, xi_psi) float64 ...
#     visc_factor       (eta_rho, xi_rho) float64 ...
# ...

# %% [markdown]
# ### Compare time

# %% [markdown]
# #### River runoff

# %%
rivers.river_time.values[530:550]
# Out:
# array(['1992-03-15T00:00:00.000000000', '1992-04-15T00:00:00.000000000',
#        '1992-05-15T00:00:00.000000000', '1992-06-15T00:00:00.000000000',
#        '1992-07-15T00:00:00.000000000', '1992-08-15T00:00:00.000000000',
#        '1992-09-15T00:00:00.000000000', '1992-10-15T00:00:00.000000000',
#        '1992-11-15T00:00:00.000000000', '1992-12-15T00:00:00.000000000',
#        '1993-01-15T00:00:00.000000000', '1993-02-15T00:00:00.000000000',
#        '1993-03-15T00:00:00.000000000', '1993-04-15T00:00:00.000000000',
#        '1993-05-15T00:00:00.000000000', '1993-06-15T00:00:00.000000000',
#        '1993-07-15T00:00:00.000000000', '1993-08-15T00:00:00.000000000',
#        '1993-09-15T00:00:00.000000000', '1993-10-15T00:00:00.000000000'],
#       dtype='datetime64[ns]')

# %%
print(rivers.river_time.values[540])
print(rivers.river_time.values[540].astype(int))
# Out:
# 1993-01-15T00:00:00.000000000
# 727056000000000000

# %% [markdown]
# The river input contains montlhy values for 1948 untill 2019, for each month the value is given for day 15. The datatime is given in [ns]
#
# The time is given as nanoseconds since 1948-01-01.

# %%
data_an
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 37984, lat: 137, lon: 153)
# Coordinates:
#   * time     (time) datetime64[ns] 1993-01-01 ... 2018-12-31T18:00:00
#   * lon      (lon) float32 -24.0 -23.75 -23.5 -23.25 ... 13.25 13.5 13.75 14.0
#   * lat      (lat) float32 32.0 32.25 32.5 32.75 33.0 ... 65.25 65.5 65.75 66.0
# Data variables:
#     Uwind    (time, lat, lon) float32 ...
#     Vwind    (time, lat, lon) float32 ...
#     cloud    (time, lat, lon) float32 ...
#     Pair     (time, lat, lon) float32 ...
#     Tair     (time, lat, lon) float32 ...
#     Qair     (time, lat, lon) float32 ...

# %% [markdown]
# #### U&V-wind, cloud coverage, air P&T, humidity

# %%
data_an.time
# Out:
# <xarray.DataArray 'time' (time: 37984)>
# array(['1993-01-01T00:00:00.000000000', '1993-01-01T06:00:00.000000000',
#        '1993-01-01T12:00:00.000000000', ..., '2018-12-31T06:00:00.000000000',
#        '2018-12-31T12:00:00.000000000', '2018-12-31T18:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 1993-01-01 ... 2018-12-31T18:00:00
# Attributes:
#     long_name:      time
#     standard_name:  time

# %%
print(data_an.time.values[56])
print(data_an.time.values[56].astype(int))
# Out:
# 1993-01-15T00:00:00.000000000
# 727056000000000000

# %% [markdown]
# The atmospheric wind, cloud, pressure, temperature and humidity contains 6-hourly data at 0,6:00, 12:00 and 18:00. The datetime is given in [ns].
#
# The time is given as nanoseconds since 1948-01-01.

# %% [markdown]
# #### Solar radiation

# %%
data_fc.time_swrad
# Out:
# <xarray.DataArray 'time_swrad' (time_swrad: 9496)>
# array(['1993-01-01T12:00:00.000000000', '1993-01-02T12:00:00.000000000',
#        '1993-01-03T12:00:00.000000000', ..., '2018-12-29T12:00:00.000000000',
#        '2018-12-30T12:00:00.000000000', '2018-12-31T12:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * time_swrad  (time_swrad) datetime64[ns] 1993-01-01T12:00:00 ... 2018-12-3...
# Attributes:
#     long_name:      time
#     standard_name:  time

# %%
print(data_fc.time_swrad.values[14])
print(data_fc.time_swrad.values[14].astype(int))
# Out:
# 1993-01-15T12:00:00.000000000
# 727099200000000000

# %%
print(data_an.time.values[58])
print(data_an.time.values[58].astype(int))
# Out:
# 1993-01-15T12:00:00.000000000
# 727099200000000000

# %% [markdown]
# The atmospheric solar radiation contains daily data at midday 12:00. The datetime is given in [ns].
#
# The time is given as nanoseconds since 1948-01-01.

# %% [markdown]
# #### Total precipitation

# %%
data_fc.time_rain

# %%
print(data_fc.time_rain.values[29])
print(data_fc.time_rain.values[29].astype(int))
# Out:
# 1993-01-15T06:00:00.000000000
# 727077600000000000

# %%
print(data_an.time.values[57])
print(data_an.time.values[57].astype(int))
# Out:
# 1993-01-15T06:00:00.000000000
# 727077600000000000

# %% [markdown]
# The atmospheric total precipitation contains 12-hourly data at 6:00 and 12:00. The datetime is given in [ns].
#
# The time is given as nanoseconds since 1948-01-01.

# %% [markdown]
# #### Boundary forcing

# %%
smooth_bry.ocean_time
# Out:
# <xarray.DataArray 'ocean_time' (ocean_time: 312)>
# array(['1993-01-15T00:00:00.000000000', '1993-02-15T00:00:00.000000000',
#        '1993-03-15T00:00:00.000000000', ..., '2018-10-15T00:00:00.000000000',
#        '2018-11-15T00:00:00.000000000', '2018-12-15T00:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * ocean_time  (ocean_time) datetime64[ns] 1993-01-15 1993-02-15 ... 2018-12-15
# Attributes:
#     long_name:  seconds since 1948-01-01 00:00:00
#     field:      time, scalar, series

# %%
print(smooth_bry.ocean_time.values[0])
print(smooth_bry.ocean_time.values[0].astype(int))
# Out:
# 1993-01-15T00:00:00.000000000
# 727056000000000000

# %%
print(data_an.time.values[56])
print(data_an.time.values[56].astype(int))
# Out:
# 1993-01-15T00:00:00.000000000
# 727056000000000000

# %% [markdown]
# The boundary forcing file contains monthly data at midnight for every 15th day. The datetime is given in [ns].
#
# The time is given as nanoseconds since 1948-01-01.

# %%
smooth_clim.ocean_time
# Out:
# <xarray.DataArray 'ocean_time' (ocean_time: 312)>
# array(['1993-01-15T00:00:00.000000000', '1993-02-15T00:00:00.000000000',
#        '1993-03-15T00:00:00.000000000', ..., '2018-10-15T00:00:00.000000000',
#        '2018-11-15T00:00:00.000000000', '2018-12-15T00:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * ocean_time  (ocean_time) datetime64[ns] 1993-01-15 1993-02-15 ... 2018-12-15
# Attributes:
#     long_name:  seconds since 1948-01-01 00:00:00
#     field:      time, scalar, series

# %%
print(smooth_clim.ocean_time.values[0])
print(smooth_clim.ocean_time.values[0].astype(int))
# Out:
# 1993-01-15T00:00:00.000000000
# 727056000000000000

# %% [markdown]
# The climatology forcing file contains montlhy data at midnight for every 15th day. The datetime is given in [ns].
#
# The time is given as nanoseconds since 1948-01-01.

# %% [markdown]
# #### Restart file

# %%
smooth_nv.ocean_time
# Out:
# <xarray.DataArray 'ocean_time' (ocean_time: 1)>
# array(['1993-01-15T00:00:00.000000000'], dtype='datetime64[ns]')
# Coordinates:
#   * ocean_time  (ocean_time) datetime64[ns] 1993-01-15
# Attributes:
#     axis:           T
#     long_name:      time since initialization
#     standard_name:  time

# %%
print(smooth_nv.ocean_time.values[0])
print(smooth_nv.ocean_time.values[0].astype(int))
# Out:
# 1993-01-15T00:00:00.000000000
# 727056000000000000

# %% [markdown]
# The restart file contains 1 date: '1993-01-15T00:00:00.000000000'.
#
# It is given as nanoseconds since 1948-01-01

# %% [markdown]
# #### Conclusions time comparison
#
# 6hourly (wind, T, P, humidity, cloud): 00:00, 06:00, 12:00 en 18:00
#
# 12hourly (total precipitation): 06:00 en 18:00
#
# daily (solar rad): 12:00
#
# Boundary forcing (monthly at 15): 00:00
#
# River run-off (monthly at 15): 00:00
#
# Climatology forcing (monthly at 15): 00:00
#
#
# All files contain nanoseconds since 1948-01-01
