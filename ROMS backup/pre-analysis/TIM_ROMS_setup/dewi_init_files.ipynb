# %% [markdown]
# ## Notebook to check Dewi's initial files and merge them

# %% [markdown]
# Dewi's file is only till 2003 while Tim's setup runs till later. Is this also true for the grid file? Maybe this means I have to just run till 2003 first.

# %%
import xarray as xr

# %%
files = xr.open_mfdataset('/Users/iriskeizer/Documents/ROMS/timnorthsea8/NS8_ForcingSmooth01/NS8_init*.nc')

# %%
files
# Out:
# <xarray.Dataset>
# Dimensions:     (ocean_time: 2, eta_rho: 218, xi_rho: 242, eta_u: 218, xi_u: 241, eta_v: 217, xi_v: 242, eta_psi: 217, xi_psi: 241, s_rho: 30, s_w: 31)
# Coordinates:
#   * s_rho       (s_rho) float64 -0.9833 -0.95 -0.9167 ... -0.05 -0.01667
#   * s_w         (s_w) float64 -1.0 -0.9667 -0.9333 ... -0.06667 -0.03333 0.0
#   * ocean_time  (ocean_time) datetime64[ns] 1993-01-15 2003-01-15
# Dimensions without coordinates: eta_rho, xi_rho, eta_u, xi_u, eta_v, xi_v, eta_psi, xi_psi
# Data variables: (12/23)
#     lon_rho     (ocean_time, eta_rho, xi_rho) float64 dask.array<chunksize=(1, 218, 242), meta=np.ndarray>
#     lat_rho     (ocean_time, eta_rho, xi_rho) float64 dask.array<chunksize=(1, 218, 242), meta=np.ndarray>
#     lon_u       (ocean_time, eta_u, xi_u) float64 dask.array<chunksize=(1, 218, 241), meta=np.ndarray>
#     lat_u       (ocean_time, eta_u, xi_u) float64 dask.array<chunksize=(1, 218, 241), meta=np.ndarray>
# ...

# %%
files.to_netcdf('/Users/iriskeizer/Documents/ROMS/timnorthsea8/NS8_init_GLORYS_1993_2003.nc')
