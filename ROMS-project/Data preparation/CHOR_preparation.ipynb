# %% [markdown]
# # Notebook to prepare the CHOR data
#
# The data is saved at '/Users/iriskeizer/Documents/ROMS/data/lateral forcing/'
#
# The data consists of 4 ensemble members:
# CHOR_AS, CHOR_RL, CHORE_AS, CHORE_RL
#
# The data consists of netcdf files for each ensemble member for each year.
#
# We want to extract the variables Temperature, Salinity, SSH, zonal currents and meridional currents
# We want to select the region from 33°N to 66°N and 12°E to 23°W
#
# The new data should be saved in the folder '/Users/iriskeizer/Documents/ROMS/data/lateral forcing/

# %%
# Import necessary packages

import xarray as xr
import netCDF4 as nc

# %%
# Import files
file = '/Users/iriskeizer/Documents/ROMS/data/lateral forcing/CHOR/CHOR_AS/CHOR_AS_1900.nc'
data = xr.open_dataset(file)

# %%
data
# Out:
# <xarray.Dataset>
# Dimensions:       (time_counter: 12, y: 511, x: 722, z: 75)
# Coordinates:
#   * time_counter  (time_counter) datetime64[ns] 1900-01-16T12:00:00 ... 1900-...
# Dimensions without coordinates: y, x, z
# Data variables: (12/18)
#     iicethic      (time_counter, y, x) float32 ...
#     iicevelu      (time_counter, y, x) float32 ...
#     iicevelv      (time_counter, y, x) float32 ...
#     ileadfra      (time_counter, y, x) float32 ...
#     isnowthi      (time_counter, y, x) float32 ...
#     sohefldo      (time_counter, y, x) float32 ...
#     ...            ...
#     sowaflup      (time_counter, y, x) float32 ...
#     sozotaux      (time_counter, y, x) float32 ...
#     vomecrty      (time_counter, z, y, x) float32 ...
#     vosaline      (time_counter, z, y, x) float32 ...
#     votemper      (time_counter, z, y, x) float32 ...
#     vozocrtx      (time_counter, z, y, x) float32 ...

# %%
data.vomecrty
# Out:
# <xarray.DataArray 'vomecrty' (time_counter: 12, z: 75, y: 511, x: 722)>
# [332047800 values with dtype=float32]
# Coordinates:
#   * time_counter  (time_counter) datetime64[ns] 1900-01-16T12:00:00 ... 1900-...
# Dimensions without coordinates: z, y, x
# Attributes:
#     units:      m s-1
#     long_name:  Meridional Current
#     grid:       v

# %%
data.vosaline
# Out:
# <xarray.DataArray 'vosaline' (time_counter: 12, z: 75, y: 511, x: 722)>
# [332047800 values with dtype=float32]
# Coordinates:
#   * time_counter  (time_counter) datetime64[ns] 1900-01-16T12:00:00 ... 1900-...
# Dimensions without coordinates: z, y, x
# Attributes:
#     units:      psu
#     long_name:  Seawater salinity
#     grid:       t

# %%
data.votemper
# Out:
# <xarray.DataArray 'votemper' (time_counter: 12, z: 75, y: 511, x: 722)>
# [332047800 values with dtype=float32]
# Coordinates:
#   * time_counter  (time_counter) datetime64[ns] 1900-01-16T12:00:00 ... 1900-...
# Dimensions without coordinates: z, y, x
# Attributes:
#     units:      degC
#     long_name:  Seawater potential temperature
#     grid:       t

# %%
data.vozocrtx
# Out:
# <xarray.DataArray 'vozocrtx' (time_counter: 12, z: 75, y: 511, x: 722)>
# [332047800 values with dtype=float32]
# Coordinates:
#   * time_counter  (time_counter) datetime64[ns] 1900-01-16T12:00:00 ... 1900-...
# Dimensions without coordinates: z, y, x
# Attributes:
#     units:      m s-1
#     long_name:  Zonal Current
#     grid:       u

# %%
data.sossheig
# Out:
# <xarray.DataArray 'sossheig' (time_counter: 12, y: 511, x: 722)>
# [4427304 values with dtype=float32]
# Coordinates:
#   * time_counter  (time_counter) datetime64[ns] 1900-01-16T12:00:00 ... 1900-...
# Dimensions without coordinates: y, x
# Attributes:
#     units:      m
#     long_name:  Sea surface height
#     grid:       t
