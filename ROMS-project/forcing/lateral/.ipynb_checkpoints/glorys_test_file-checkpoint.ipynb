# %% [markdown]
# ## Create a glorys test file of data

# %%
import xarray as xr

# %%
glorys_test = xr.open_mfdataset('/Users/iriskeizer/Documents/ROMS/data/GLORYS12V1/input/CMEMS*').load()

# %%
glorys_test.close()

# %%
glorys_test.to_netcdf('/Users/iriskeizer/Documents/ROMS/code/model2roms4/glorys_test.nc')

# %%
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 24, depth: 50, latitude: 313, longitude: 361)
# Coordinates:
#   * depth      (depth) float32 0.494 1.541 2.646 ... 5.275e+03 5.728e+03
#   * latitude   (latitude) float32 36.0 36.08 36.17 36.25 ... 61.83 61.92 62.0
#   * time       (time) datetime64[ns] 1993-01-16T12:00:00 ... 1994-12-16T12:00:00
#   * longitude  (longitude) float32 -20.0 -19.92 -19.83 ... 9.833 9.917 10.0
# Data variables:
#     so         (time, depth, latitude, longitude) float32 36.56 36.55 ... nan
#     thetao     (time, depth, latitude, longitude) float32 17.99 18.05 ... nan
#     uo         (time, depth, latitude, longitude) float32 -0.05737 ... nan
#     vo         (time, depth, latitude, longitude) float32 0.0647 0.08606 ... nan
#     zos        (time, latitude, longitude) float32 -0.2982 -0.2936 ... nan nan
# Attributes: (12/17)
#     title:                         Monthly mean fields for product GLOBAL_REA...
# ...
