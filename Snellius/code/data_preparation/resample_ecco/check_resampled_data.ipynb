# %% [markdown]
# # Check the resampled data

# %%
import xarray as xr

# %%
salt = xr.open_dataset('/projects/0/einf2878/ROMS/data/ECCO/resampled_test/salt.nc')

# %%
salt.isel(time=0, k=0).SALT.plot(vmin = 33, vmax = 39)

# %%
path_input_data = '/projects/0/einf2878/ROMS/data/ECCO/nctiles/'
variable = 'salt'

salt_original = xr.open_mfdataset(f'{path_input_data}/{variable}/*.nc')

# %%
salt_original.isel(time=0, k=0, tile = 2, i = range(22, 48), j = range(29, 67)).SALT.plot(vmin = 33, vmax = 39)
