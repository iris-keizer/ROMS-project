# %%
import xarray as xr

# %% [markdown]
# ## Check rst file

# %%
rst = xr.open_dataset('/projects/0/einf2878/output/run5/NorthSea4_rst.nc')

# %%
rst.isel(ocean_time = -1).zeta.plot()

# %%
rst.isel(ocean_time = -1).ubar.plot()

# %%
rst.isel(ocean_time = -1).vbar.plot()

# %%
rst.isel(ocean_time = -1, s_rho = 0).temp.plot()

# %%
rst.isel(ocean_time = -1, s_rho = -1).temp.plot()

# %%
rst.isel(ocean_time = -1, s_rho = 0).temp.plot()

# %%
rst.isel(ocean_time = -1, s_rho = -1).salt.plot()

# %%
rst.isel(ocean_time = -1, s_rho = 0).salt.plot()

# %%
rst.isel(ocean_time = -1, s_rho = -1).u.plot()

# %%
rst.isel(ocean_time = -1, s_rho = 0).u.plot()

# %%
rst.isel(ocean_time = -1, s_rho = -1).v.plot()

# %%
rst.isel(ocean_time = -1, s_rho = 0).v.plot()

# %%
rst.Hsbl.isel(ocean_time = -1).plot()

# %% [markdown]
# ## Check ERA5 surface input

# %%
era_fc = xr.open_dataset('/home/ikeizer/NorthSea4/ERA5_NorthAtlantic_fc_ForROMS.nc')

# %%
era_fc.rain.isel(time_rain = 23096).plot()

# %%
era_fc.rain.isel(time_rain = 23095).plot()

# %%
era_fc.rain.isel(time_rain = 0).plot()

# %%
era_fc.rain.max()
# Out:
# <xarray.DataArray 'rain' ()>
# array(0.00374881)

# %%
era_fc.swrad.isel(time_swrad = 0).plot()

# %%
era_fc.swrad.isel(time_swrad = 13000).plot()

# %%
era_fc.swrad.isel(time_swrad = 20000).plot()
